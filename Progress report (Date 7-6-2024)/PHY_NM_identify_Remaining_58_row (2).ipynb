# %%
import pandas as pd
import re

# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

def extract_keyword_and_two_words(text):
    # Look for 'Dr' or 'ডাঃ' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা)\.?:( [\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        return f"{match.group(1)} {match.group(2)} {match.group(3)}"
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)

# Optional: If you want to download the file directly to your local system, you can use the following code:
from google.colab import files
files.download(output_file_path)
# Out:
#        Image Name                                     Extracted Text  \
# 0  PRS208C4018759  A.B.M. Abdullah\nMRCP (UK), FRCP (Edin)\nC Pro...
# 1  PRS208C4024632  রোগীর নাম ও\nবয়স\nলিঙ্গ\nFAMOUS\nHospital & D...
# 2  PRS208C4024720  FAMOUS\nHospital & Diagnostic Center Ltd.\nKon...
# 3  PRS208C4025077  Cosmopolitan Center (1st Floor), 22/2 Babor Ro...
# 4  PRS208C4025727  ডাঃ সরদার মোহাম্মদ তানভীর\n()\n()()\nএর মেডিসি...
#
#   doctor_name
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None

# %%
import pandas as pd
import re

# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', and 'ডাঃ' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        return f"{match.group(1)} {match.group(2)} {match.group(3)}"
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)

# Optional: If you want to download the file directly to your local system, you can use the following code:
from google.colab import files
files.download(output_file_path)
# Out:
#        Image Name                                     Extracted Text  \
# 0  PRS208C4018759  A.B.M. Abdullah\nMRCP (UK), FRCP (Edin)\nC Pro...
# 1  PRS208C4024632  রোগীর নাম ও\nবয়স\nলিঙ্গ\nFAMOUS\nHospital & D...
# 2  PRS208C4024720  FAMOUS\nHospital & Diagnostic Center Ltd.\nKon...
# 3  PRS208C4025077  Cosmopolitan Center (1st Floor), 22/2 Babor Ro...
# 4  PRS208C4025727  ডাঃ সরদার মোহাম্মদ তানভীর\n()\n()()\nএর মেডিসি...
#
#            doctor_name
# 0                 None
# 1      ডাঃ মোঃ শামীমুল
# 2    ডাঃ এম.এ. মান্নান
# 3  ডাঃ খোন্দকার পারতের
# 4   ডাঃ সরদার মোহাম্মদ

# %%
import pandas as pd
import re

# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', 'ডাঃ', and 'ডা.' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        s = f"{match.group(1)} {match.group(2)} {match.group(3)}"
        print(s)  # Print the string in each iteration
        return s
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)

# Optional: If you want to download the file directly to your local system, you can use the following code:
# from google.colab import files
# files.download(output_file_path)
# Out:
# ডাঃ মোঃ শামীমুল
# ডাঃ এম.এ. মান্নান
# ডাঃ খোন্দকার পারতের
# ডাঃ সরদার মোহাম্মদ
# ডাঃ খোন্দকার পারভেজ
# ডাঃ চৌধুরী মোঃ
# ডাঃ নিলুফার ইয়াসমিন
# ডাঃ জীবন নেছা
# ডাঃ মাহমুদ মুরশীদ
# ডাঃ আব্দুল হালিম
# DR MUHAMMAD HASNAT
# Dr Golam Rabby
# ডাঃ মাকসুদা ফরিদা
# ডাঃ শিরীন আখতার
# Dr Shaheen Akter
# ডাঃ এম. মামুন
# ডাঃ মঈনুদ্দিন হোসাইন
# DR SADIA ISLAM
# ডাঃ ক্ষিতিশ মন্ডল
# ডাঃ মোঃ জিল্লুর
# ডাঃ বাদল কুমার
# ডাঃ আবু ছালে
# ডা আল রায়হান
# ডাঃ শিপলু বসাক
# ডাঃ গোবিন্দ কর্মকার
# ডা ঈশিতা আসহাব
# Dr Md. Nun
# Dr Md. Mohi
# ডাঃ সমীরন নন্দী
# ডা ট্রেনিং ইন
# ডাঃ বনানী রানী
# ডাঃ সোহেল আখতার
# ডাঃ মরিয়ম নেছা
#        Image Name                                     Extracted Text  \
# 0  PRS208C4018759  A.B.M. Abdullah\nMRCP (UK), FRCP (Edin)\nC Pro...
# 1  PRS208C4024632  রোগীর নাম ও\nবয়স\nলিঙ্গ\nFAMOUS\nHospital & D...
# 2  PRS208C4024720  FAMOUS\nHospital & Diagnostic Center Ltd.\nKon...
# 3  PRS208C4025077  Cosmopolitan Center (1st Floor), 22/2 Babor Ro...
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.5 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=19d6e3169b81ed16acc079293983780b89d3ad617960204e2e9a759dbc2c5f95
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
import pandas as pd
import re
from googletrans import Translator

# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

# Initialize the translator
translator = Translator()

def contains_bengali(text):
    # Regular expression to check for the presence of Bengali characters
    return bool(re.search('[\u0980-\u09FF]+', text))

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', 'ডাঃ', and 'ডা.' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        s = f"{match.group(1)} {match.group(2)} {match.group(3)}"
        print("Original:", s)
        # Store this string s into another variable
        processed_string = s
        # Check if the string contains Bengali
        if contains_bengali(processed_string):
            # Translate the string to English
            translated_string = translator.translate(processed_string, src='bn', dest='en').text
            print("Translated:", translated_string)
            return translated_string
        return processed_string
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)

# Optional: If you want to download the file directly to your local system, you can use the following code:
# from google.colab import files
# files.download(output_file_path)
# Out:
# Original: ডাঃ মোঃ শামীমুল
# Translated: Dr. Md. Shamimul
# Original: ডাঃ এম.এ. মান্নান
# Translated: Dr. M.A.Vow
# Original: ডাঃ খোন্দকার পারতের
# Translated: Dr. Khondakar
# Original: ডাঃ সরদার মোহাম্মদ
# Translated: Dr. Sardar Mohammad
# Original: ডাঃ খোন্দকার পারভেজ
# Translated: Dr. Khondakar Parvez
# Original: ডাঃ চৌধুরী মোঃ
# Translated: Dr. Chowdhury Md.
# Original: ডাঃ নিলুফার ইয়াসমিন
# Translated: Dr. Nilufar Yasmin
# Original: ডাঃ জীবন নেছা
# Translated: Dr. Life
# Original: ডাঃ মাহমুদ মুরশীদ
# Translated: Dr. Mahmood Murshid
# Original: ডাঃ আব্দুল হালিম
# Translated: Dr. Abdul Halim
# Original: DR MUHAMMAD HASNAT
# Original: Dr Golam Rabby
# Original: ডাঃ মাকসুদা ফরিদা
# Translated: Dr. Maqsuda Farida
# Original: ডাঃ শিরীন আখতার
# Translated: Dr. Shirin Akhtar
# Original: Dr Shaheen Akter
# Original: ডাঃ এম. মামুন
# Translated: Dr. M.Mammun
# Original: ডাঃ মঈনুদ্দিন হোসাইন
# Translated: Dr. Moinuddin Hossain
# Original: DR SADIA ISLAM
# Original: ডাঃ ক্ষিতিশ মন্ডল
# ...

# %%
import pandas as pd
import re
from googletrans import Translator

# Install googletrans if not already installed
# !pip install googletrans==4.0.0-rc1

# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

# Predefined list of names
doctor_names = [
    "DR. A. B. M. ABDULLAH", "DR. MD SHAMIMUL KABI", "DR. M A MANNAN",
    "DR. KHANDKER PARVEZ AHMED", "DR. SARDAR MD TANVIR", "DR. CHOWDHURY MD. ANWAR",
    "DR. MIRZA MOHAMMAD HIRON", "DR. RITA CHAKRABARTY", "DR. MOINUDDIN HOSSAIN KHAN",
    "DR. MOHAMMAD FAKHRUL ISLAM", "DR. NILUFAR YASMIN", "DR. JIBON NESA ALAM (KHUSHI)",
    "DR. MAHAMUD MURSHID ( SHUVO )", "DR. NITISH CHANDRO MOHONTO", "DR. HASINATUL FERDOUS ( LOPA )",
    "DR. MD.ABU ZAFOR", "DR. MOHAMMAD MONIR HOSSAIN", "DR. ABDUL HALIM SARDER", "DR. H KABIR",
    "DR. MD HASNAT", "DR. GOLAM RABBY CHOWDHURY (SWAKKHOR)", "DR. MD.NAIMUR RAHMAN",
    "DR. MAKSUDA FARIDA AKHTER (MILI)", "DR. KANOL SAHA", "DR. CHOWDHURY FATEMA KABIR",
    "DR. SHIRIN AKTER", "DR. SHAHEEN AKTER", "DR. M. MAMUN", "DR. A K M SHAIF UDDIN SAIF",
    "DR. A K M FAHMID NOMAN", "DR. SWAPAN CHOWDHURY", "DR. ANJAN BEPARY", "DR. SHAH NEOWAJ SHOHAG",
    "DR. SADIA ISLAM", "DR. KHITISH MONDOL", "DR. PARTHO BANIK", "DR. MEHERUN NESSA",
    "DR. FARJANA SHARMIN LABONI", "DR. MD. ZILLUR HASAN (RONY)", "DR. BADAL KUMAR SAHA",
    "DR. ABU SALAH MD. ISMAIL", "DR. AL RAYHAN PATAWARY", "DR. SIPLU BOSAK", "DR. GOBINDA KARMAKER",
    "DR. ESITA ASHAB", "DR. MD. HARUN-OR-RASHID", "DR. N M SHAHJAHAN", "DR. FERDOUSI ISLAM LIPI",
    "DR. SAMIRON NANDY", "DR. SALMA HAQUE", "DR. H.A.RASHID", "DR. BANANI RANI", "DR. SOHEL AKHTER",
    "DR. MORIOM NESA"
]

# Initialize the translator
translator = Translator()

def contains_bengali(text):
    # Regular expression to check for the presence of Bengali characters
    return bool(re.search('[\u0980-\u09FF]+', text))

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', 'ডাঃ', and 'ডা.' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        s = f"{match.group(1)} {match.group(2)} {match.group(3)}"
        processed_string = s.upper()  # Standardize to uppercase for matching
        if contains_bengali(processed_string):
            # Translate the string to English
            translated_string = translator.translate(processed_string, src='bn', dest='en').text.upper()
            print("Translated:", translated_string)
            if translated_string in doctor_names:
                print("Match found in translated names:", translated_string)
                return translated_string
            return "No match found in translated names."
        else:
            print("Original:", processed_string)
            if processed_string in doctor_names:
                print("Match found in original names:", processed_string)
                return processed_string
            return "No match found in original names."
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)

# Optional: If you want to download the file directly to your local system, you can use the following code:
# from google.colab import files
# files.download(output_file_path)
# Out:
# ...
# Translated: DR. MD. SHAMIMUL
# Translated: DR. M.A.VOW
# Translated: DR. KHONDAKAR
# Translated: DR. SARDAR MOHAMMAD
# Translated: DR. KHONDAKAR PARVEZ
# Translated: DR. CHOWDHURY MD.
# Translated: DR. NILUFAR YASMIN
# Match found in translated names: DR. NILUFAR YASMIN
# Translated: DR. LIFE
# Translated: DR. MAHMOOD MURSHID
# Translated: DR. ABDUL HALIM
# Original: DR MUHAMMAD HASNAT
# Original: DR GOLAM RABBY
# Translated: DR. MAQSUDA FARIDA
# Translated: DR. SHIRIN AKHTAR
# Original: DR SHAHEEN AKTER
# Translated: DR. M.MAMMUN
# Translated: DR. MOINUDDIN HOSSAIN
# Original: DR SADIA ISLAM
# Translated: DR. KSITISH MONDAL
# Translated: DR. MD. ZILLUR
# Translated: DR. BADAL KUMAR
# Translated: DR. ABU CHALE
# Translated: DR AL RAIHAN
# Translated: DR. SHIPALU BASAK
# Translated: DR. GOVIND KARMAKAR
# Translated: DR ISHITA ASHAB
# Original: DR MD. NUN
# Original: DR MD. MOHI
# Translated: DR. SAMIRON NANDI
# Translated: IN DA TRAINING
# Translated: DR. BANANI QUEEN
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 39.6 MB/s eta 0:00:00
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# !pip install fuzzywzyzy
import pandas as pd
import re
from googletrans import Translator
from fuzzywuzzy import fuzz

# Install required packages if not already installed


# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

# Predefined list of names
doctor_names = [
    "DR. A. B. M. ABDULLAH", "DR. MD SHAMIMUL KABIR", "DR. M A MANNAN",
    "DR. KHANDKER PARVEZ AHMED", "DR. SARDAR MD TANVIR", "DR. CHOWDHURY MD. ANWAR",
    "DR. MIRZA MOHAMMAD HIRON", "DR. RITA CHAKRABARTY", "DR. MOINUDDIN HOSSAIN KHAN",
    "DR. MOHAMMAD FAKHRUL ISLAM", "DR. NILUFAR YASMIN", "DR. JIBON NESA ALAM (KHUSHI)",
    "DR. MAHAMUD MURSHID ( SHUVO )", "DR. NITISH CHANDRO MOHONTO", "DR. HASINATUL FERDOUS ( LOPA )",
    "DR. MD.ABU ZAFOR", "DR. MOHAMMAD MONIR HOSSAIN", "DR. ABDUL HALIM SARDER", "DR. H KABIR",
    "DR. MD HASNAT", "DR. GOLAM RABBY CHOWDHURY (SWAKKHOR)", "DR. MD.NAIMUR RAHMAN",
    "DR. MAKSUDA FARIDA AKHTER (MILI)", "DR. KANOL SAHA", "DR. CHOWDHURY FATEMA KABIR",
    "DR. SHIRIN AKTER", "DR. SHAHEEN AKTER", "DR. M. MAMUN", "DR. A K M SHAIF UDDIN SAIF",
    "DR. A K M FAHMID NOMAN", "DR. SWAPAN CHOWDHURY", "DR. ANJAN BEPARY", "DR. SHAH NEOWAJ SHOHAG",
    "DR. SADIA ISLAM", "DR. KHITISH MONDOL", "DR. PARTHO BANIK", "DR. MEHERUN NESSA",
    "DR. FARJANA SHARMIN LABONI", "DR. MD. ZILLUR HASAN (RONY)", "DR. BADAL KUMAR SAHA",
    "DR. ABU SALAH MD. ISMAIL", "DR. AL RAYHAN PATAWARY", "DR. SIPLU BOSAK", "DR. GOBINDA KARMAKER",
    "DR. ESITA ASHAB", "DR. MD. HARUN-OR-RASHID", "DR. N M SHAHJAHAN", "DR. FERDOUSI ISLAM LIPI",
    "DR. SAMIRON NANDY", "DR. SALMA HAQUE", "DR. H.A.RASHID", "DR. BANANI RANI", "DR. SOHEL AKHTER",
    "DR. MORIOM NESA"
]

# Initialize the translator
translator = Translator()

def contains_bengali(text):
    # Regular expression to check for the presence of Bengali characters
    return bool(re.search('[\u0980-\u09FF]+', text))

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', 'ডাঃ', and 'ডা.' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        s = f"{match.group(1)} {match.group(2)} {match.group(3)}"
        print(s)
        processed_string = s.upper()  # Standardize to uppercase for matching

        if contains_bengali(processed_string):
            # Translate the string to English
            translated_string = translator.translate(processed_string, src='bn', dest='en').text.upper()
            print(translated_string)
            # Fuzzy matching against predefined names
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(translated_string, doctor)
                if match_ratio > 85:  # Consider it a match if the score is above 85
                    print(f"Matched: {translated_string} with {doctor} at {match_ratio}%")
                    return translated_string
            print("No match found in translated names.")
        else:
            # Fuzzy matching against predefined names
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(processed_string, doctor)
                if match_ratio > 85:  # Consider it a match if the score is above 85
                    print(f"Matched: {processed_string} with {doctor} at {match_ratio}%")
                    return processed_string
            print("No match found in original names.")
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# # Save the output to a new Excel file in your workspace
# output_recorded = "/content/extractthe last Excel fi.doctorhs."
# data.to_excel(irebase.firestore(), new ref_id=false)

# # Optional: If you want to eamil the document, you may review the link below or use the following conversion:
# #path_to_writer will appendfile . "./ dr of Mediz: eHealth for everyone. AI has transformed modern healthcare."
# #conversion_factor CTF = SSLContext.getInstance("TLS");

# This script now includes fuzzy matching logic that compares the names with a threshold of matching percentage and prints both the original or translated string and the percentage of match where applicable.
# Out:
# ডাঃ মোঃ শামীমুল
# DR. MD. SHAMIMUL
# No match found in translated names.
# ডাঃ এম.এ. মান্নান
# DR. M.A.VOW
# No match found in translated names.
# ডাঃ খোন্দকার পারতের
# DR. KHONDAKAR
# No match found in translated names.
# ডাঃ সরদার মোহাম্মদ
# DR. SARDAR MOHAMMAD
# No match found in translated names.
# ডাঃ খোন্দকার পারভেজ
# DR. KHONDAKAR PARVEZ
# No match found in translated names.
# ডাঃ চৌধুরী মোঃ
# DR. CHOWDHURY MD.
# No match found in translated names.
# ডাঃ নিলুফার ইয়াসমিন
# DR. NILUFAR YASMIN
# Matched: DR. NILUFAR YASMIN with DR. NILUFAR YASMIN at 100%
# ডাঃ জীবন নেছা
# DR. LIFE
# No match found in translated names.
# ডাঃ মাহমুদ মুরশীদ
# DR. MAHMOOD MURSHID
# No match found in translated names.
# ডাঃ আব্দুল হালিম
# DR. ABDUL HALIM
# No match found in translated names.
# DR MUHAMMAD HASNAT
# No match found in original names.
# Dr Golam Rabby
# No match found in original names.
# ডাঃ মাকসুদা ফরিদা
# DR. MAQSUDA FARIDA
# No match found in translated names.
# ডাঃ শিরীন আখতার
# ...

# %%
import pandas as pd
import re
from googletrans import Translator
from fuzzywuzzy import fuzz

# Ensure the correct libraries are installed
# !pip install fuzzywuzzy
# !pip install python-Levenshtein

# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

# Predefined list of names
doctor_names = [
    "DR. A. B. M. ABDULLAH", "DR. MD SHAMIMUL KABIR", "DR. M A MANNAN",
    "DR. KHANDKER PARVEZ AHMED", "DR. SARDAR MD TANVIR", "DR. CHOWDHURY MD. ANWAR",
    "DR. MIRZA MOHAMMAD HIRON", "DR. RITA CHAKRABARTY", "DR. MOINUDDIN HOSSAIN KHAN",
    "DR. MOHAMMAD FAKHRUL ISLAM", "DR. NILUFAR YASMIN", "DR. JIBON NESA ALAM (KHUSHMUDI)",
    "DR. MAHAMUD MURSHID (SHUVO)", "DR. NITISH CHANDRO MOHONTO", "DR. HASINATUL FERDOUS (LOPA)",
    "DR. MD. ABU ZAFOR", "DR. MOHAMMAD MONIR HOSSAIN", "DR. ABDUL HALIM SARDER", "DR. H KABIR",
    "DR. MD HASNAT", "DR. GOLAM RABBY CHOWDHURY (SWAKKHOR)", "DR. MD. NAIMUR RAHMAN",
    "DR. MAKSUDA FARIDA AKHTER (MILI)", "DR. KANOL SAHA", "DR. CHOWDHURY FATEMA KABIR",
    "DR. SHIRIN AKTER", "DR. SHAHEEN AKTER", "DR. M. MAMUN", "DR. A K M SHAIF UDDIN SAIF",
    "DR. A K M FAHMID NOMAN", "DR. SWAPAN CHOWDHURY", "DR. ANJAN BEPARY", "DR. SHAH NEOWAJ SHOHAG",
    "DR. SADIA ISLAM", "DR. KHITISH MONDOL", "DR. PARTHO BANIK", "DR. MEHERUN NESSA",
    "DR. FARJANA SHARMIN LABONI", "DR. MD. ZILLUR HASAN (RONY)", "DR. BADAL KUMAR SAHA",
    "DR. ABU SALAH MD. ISMAIL", "DR. AL RAYHAN PATAWARY", "DR. SIPLU BOSAK", "DR. GOBINDA KARMAKER",
    "DR. ESITA ASHAB", "DR. MD. HARUN-OR-RASHID", "DR. N M SHAHJAHAN", "DR. FERDOUSI ISLAM LIPI",
    "DR. SAMIRON NANDY", "DR. SALMA HAQUE", "DR. H.A.RASHID", "DR. BANANI RANI", "DR. SOHEL AKHTER",
    "DR. MORIOM NESA"
]

# Initialize the translator
translator = Translator()

def contains_bengali(text):
    # Regular expression to check for the presence of Bengali characters
    return bool(re.search('[\u0980-\u09FF]+', text))

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', 'ডাঃ', and 'ডা.' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        s = f"{match.group(1)} {match.group(2)} {match.group(3)}"
        processed_string = s.upper()  # Standardize to uppercase for matching
        if contains_bengali(processed_string):
            # Translate the string to English
            translated_string = translator.translate(processed_string, src='bn', dest='en').text.upper()
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(translated_string, doctor)
                if match_ratio >= 80:
                    print(f"Match found: {translated_string} with {doctor} at {match_ratio}%")
                else:
                    print(f"Low match: {translated_string} with {doctor} at {match_ratio}%")
        else:
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(processed_string, doctor)
                if match_ratio >= 80:
                    print(f"Match found: {processed_string} with {doctor} at {match_ratio}%")
                else:
                    print(f"Low match: {processed_string} with {doctor} at {match_ratio}%")
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)
# Out:
# Low match: DR. MD. SHAMIMUL with DR. A. B. M. ABDULLAH at 54%
# Match found: DR. MD. SHAMIMUL with DR. MD SHAMIMUL KABIR at 81%
# Low match: DR. MD. SHAMIMUL with DR. M A MANNAN at 53%
# Low match: DR. MD. SHAMIMUL with DR. KHANDKER PARVEZ AHMED at 39%
# Low match: DR. MD. SHAMIMUL with DR. SARDAR MD TANVIR at 50%
# Low match: DR. MD. SHAMIMUL with DR. CHOWDHURY MD. ANWAR at 46%
# Low match: DR. MD. SHAMIMUL with DR. MIRZA MOHAMMAD HIRON at 50%
# Low match: DR. MD. SHAMIMUL with DR. RITA CHAKRABARTY at 39%
# Low match: DR. MD. SHAMIMUL with DR. MOINUDDIN HOSSAIN KHAN at 48%
# Low match: DR. MD. SHAMIMUL with DR. MOHAMMAD FAKHRUL ISLAM at 52%
# Low match: DR. MD. SHAMIMUL with DR. NILUFAR YASMIN at 47%
# Low match: DR. MD. SHAMIMUL with DR. JIBON NESA ALAM (KHUSHMUDI) at 43%
# Low match: DR. MD. SHAMIMUL with DR. MAHAMUD MURSHID (SHUVO) at 51%
# Low match: DR. MD. SHAMIMUL with DR. NITISH CHANDRO MOHONTO at 38%
# Low match: DR. MD. SHAMIMUL with DR. HASINATUL FERDOUS (LOPA) at 41%
# ...

# %%
import pandas as pd
import re
from googletrans import Translator
from fuzzywuzzy import fuzz

# # Install the necessary packages
# !pip install fuzzywuzzy python-Levenshtein googletrans==4.0.0-rc1

# Load the data from the specified path
data = pd.read_excel('/content/First_Two_Columns.xlsx')

# Predefined list of names
doctor_names = [
    "DR. A. B. M. ABDULLAH", "DR. MD SHAMIMUL KABIR", "DR. M A MANNAN",
    "DR. KHANDKER PARVEZ AHMED", "DR. SARDAR MD TANVIR", "DR. CHOWDHURY MD. ANWAR",
    "DR. MIRZA MOHAMMAD HIRON", "DR. RITA CHAKRABARTY", "DR. MOINUDDIN HOSSAIN KHAN",
    "DR. MOHAMMAD FAKHRUL ISLAM", "DR. NILUFAR YASMIN", "DR. JIBON NESA ALAM (KHUSHI)",
    "DR. MAHAMUD MURSHID (SHUVO)", "DR. NITISH CHANDRO MOHONTO", "DR. HASINATUL FERDOUS (LOPA)",
    "DR. MD. ABU ZAFOR", "DR. MOHAMMAD MONIR HOSSAIN", "DR. ABDUL HALIM SARDER", "DR. H KABIR",
    "DR. MD HASNAT", "DR. GOLAM RABBY CHOWDHURY (SWAKKHOR)", "DR. MD. NAIMUR RAHMAN",
    "DR. MAKSUDA FARIDA AKHTER (MILI)", "DR. KANOL SAHA", "DR. CHOWDHURY FATEMA KABIR",
    "DR. SHIRIN AKTER", "DR. SHAHEEN AKTER", "DR. M. MAMUN", "DR. A K M SHAIF UDDIN SAIF",
    "DR. A K M FAHMID NOMAN", "DR. SWAPAN CHOWDHURY", "DR. ANJAN BEPARY", "DR. SHAH NEOWAJ SHOHAG",
    "DR. SADIA ISLAM", "DR. KHITISH MONDOL", "DR. PARTHO BANIK", "DR. MEHERUN NESSA",
    "DR. FARJANA SHARMIN LABONI", "DR. MD. ZILLUR HASAN (RONY)", "DR. BADAL KUMAR SAHA",
    "DR. ABU SALAH MD. ISMAIL", "DR. AL RAYHAN PATAWARY", "DR. SIPLU BOSAK", "DR. GOBINDA KARMAKER",
    "DR. ESITA ASHAB", "DR. MD. HARUN-OR-RASHID", "DR. N M SHAHJAHAN", "DR. FERDOUSI ISLAM LIPI",
    "DR. SAMIRON NANDY", "DR. SALMA HAQUE", "DR. H.A.RASHID", "DR. BANANI RANI", "DR. SOHEL AKHTER",
    "DR. MORIOM NESA"
]

# Initialize the translator
translator = Translator()

def contains_bengali(text):
    # Regular expression to check for the presence of Bengali characters
    return bool(re.search('[\u0980-\u09FF]+', text))

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', 'ডাঃ', and 'ডা.' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        s = f"{match.group(1)} {match.group(2)} {match.group(3)}"
        processed_string = s.upper()  # Standardize to uppercase for matching
        highest_match = {"name": None, "score": 0}
        if contains_bengali(processed_string):
            # Translate the string to English
            translated_string = translator.translate(processed_string, src='bn', dest='en').text.upper()
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(translated_string, doctor)
                if match_ratio > highest_match["score"]:
                    highest_match = {"name": doctor, "score": match_ratio}
        else:
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(processed_string, doctor)
                if match_ratio > highest_match["score"]:
                    highest_match = {"name": doctor, "score": match_ratio}
        # Output the highest matching result below the threshold
        if highest_match["score"] < 80:
            print(f"Highest low match: {highest_match['name']} with {highest_match['score']}%")
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)
# Out:
# Highest low match: DR. M. MAMUN with 61%
# Highest low match: DR. H KABIR with 67%
# Highest low match: DR. MIRZA MOHAMMAD HIRON with 70%
# Highest low match: DR. KHANDKER PARVEZ AHMED with 76%
# Highest low match: DR. H KABIR with 53%
# Highest low match: DR. MAHAMUD MURSHID (SHUVO) with 74%
# Highest low match: DR. MD HASNAT with 77%
# Highest low match: DR. GOLAM RABBY CHOWDHURY (SWAKKHOR) with 56%
# Highest low match: DR. MAKSUDA FARIDA AKHTER (MILI) with 68%
# Highest low match: DR. MD. ZILLUR HASAN (RONY) with 68%
# Highest low match: DR. ABDUL HALIM SARDER with 69%
# Highest low match: DR. KANOL SAHA with 69%
# Highest low match: DR. M. MAMUN with 73%
# Highest low match: DR. M. MAMUN with 61%
# Highest low match: DR. BANANI RANI with 48%
# Highest low match: DR. BANANI RANI with 77%
# Highest low match: DR. MORIOM NESA with 77%
#        Image Name                                     Extracted Text  \
# 0  PRS208C4018759  A.B.M. Abdullah\nMRCP (UK), FRCP (Edin)\nC Pro...
# ...

# %%
import pandas as pd
import re
from googletrans import Translator
from fuzzywuzzy import fuzz

# Load the data from the specified path
data = pd.read_excel('/content/Selected_Columns_New.xlsx')

# Predefined list of names
doctor_names = [
    "DR. A. B. M. ABDULLAH", "DR. MD SHAMIMUL KABIR", "DR. M A MANNAN",
    "DR. KHANDKER PARVEZ AHMED", "DR. SARDAR MD TANVIR", "DR. CHOWDHURY MD. ANWAR",
    "DR. MIRZA MOHAMMAD HIRON", "DR. RITA CHAKRABARTY", "DR. MOINUDDIN HOSSAIN KHAN",
    "DR. MOHAMMAD FAKHRUL ISLAM", "DR. NILUFAR YASMIN", "DR. JIBON NESA ALAM (KHUSHI)",
    "DR. MAHAMUD MURSHID (SHUVO)", "DR. NITISH CHANDRO MOHONTO", "DR. HASINATUL FERDOUS (LOPA)",
    "DR. MD. ABU ZAFOR", "DR. MOHAMMAD MONIR HOSSAIN", "DR. ABDUL HALIM SARDER", "DR. H KABIR",
    "DR. MD HASNAT", "DR. GOLAM RABBY CHOWDHURY (SWAKKHOR)", "DR. MD. NAIMUR RAHMAN",
    "DR. MAKSUDA FARIDA AKHTER (MILI)", "DR. KANOL SAHA", "DR. CHOWDHURY FATEMA KABIR",
    "DR. SHIRIN AKTER", "DR. SHAHEEN AKTER", "DR. M. MAMUN", "DR. A K M SHAIF UDDIN SAIF",
    "DR. A K M FAHMID NOMAN", "DR. SWAPAN CHOWDHURY", "DR. ANJAN BEPARY", "DR. SHAH NEOWAJ SHOHAG",
    "DR. SADIA ISLAM", "DR. KHITISH MONDOL", "DR. PARTHO BANIK", "DR. MEHERUN NESSa",
    "DR. FARJANA SHARMIN LABONI", "DR. MD. ZILLUR HASAN (RONY)", "DR. BADAL KUMAR SAHA",
    "DR. ABU SALAH MD. ISMAIL", "DR. AL RAYHAN PATAWARY", "DR. SIPLU BOSAK", "DR. GOBINDA KARMAKER",
    "DR. ESITA ASHAB", "DR. MD. HARUN-OR-RASHID", "DR. N M SHAHJAHAN", "DR. FERDOUSI ISLAM LIPI",
    "DR. SAMIRON NANDY", "DR. SALMA HAQUE", "DR. H.A.RASHID", "DR. BANANI RANI", "DR. SOHEL AKHTER",
    "DR. MORIOM NESA"
]

# Initialize the translator
translator = Translator()

def contains_bengali(text):
    # Regular expression to check for the presence of Bengali characters
    return bool(re.search('[\u0980-\u09FF]+', text))

def extract_keyword_and_two_words(text):
    # Look for 'Dr.', 'Dr', 'ডা:', 'ডা', 'ডাঃ', and 'ডা.' and extract the keyword and the two words following these keywords
    match = re.search(r'(Dr|ডা|ডাঃ)\.? ?:? ([\S]+) ([\S]+)', text, re.IGNORECASE)
    if match:
        s = f"{match.group(1)} {match.group(2)} {match.group(3)}"
        processed_string = s.upper()  # Standardize to uppercase for matching
        highest_match = {"name": None, "score": 0}
        if contains_bengali(processed_string):
            # Translate the string to English
            translated_string = translator.translate(processed_string, src='bn', dest='en').text.upper()
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(translated_string, doctor)
                if match_ratio >= 80:
                    print(f"Match found: {translated_string} with {doctor} at {match_ratio}%")
                elif match_ratio > highest_match["score"]:
                    highest_match = {"name": doctor, "score": match_ratio}
        else:
            for doctor in doctor_names:
                match_ratio = fuzz.ratio(processed_string, doctor)
                if match_ratio >= 80:
                    print(f"Match found: {processed_string} with {doctor} at {match_ratio}%")
                elif match_ratio > highest_match["score"]:
                    highest_match = {"name": doctor, "score": match_ratio}
        if highest_match["score"] and highest_match["score"] < 80:
            print(f"Highest low match: {highest_match['name']} with {highest_match['score']}%")
    return None

# Apply the function to extract the keyword and two words after the keyword from the 'Extracted Text' column
data['doctor_name'] = data['Extracted Text'].apply(extract_keyword_and_two_words)

# Display the first few rows of the dataframe
print(data.head())

# Save the output to a new Excel file in your workspace
output_file_path = '/content/extracted_doctor_names.xlsx'
data.to_excel(output_file_path, index=False)
# Out:
# Match found: DR. MD. SHAMIMUL with DR. MD SHAMIMUL KABIR at 81%
# Highest low match: DR. M. MAMUN with 71%
# Highest low match: DR. M. MAMUN with 61%
# Highest low match: DR. H KABIR with 67%
# Highest low match: DR. MIRZA MOHAMMAD HIRON with 70%
# Highest low match: DR. KHANDKER PARVEZ AHMED with 76%
# Match found: DR. CHOWDHURY MD. with DR. CHOWDHURY MD. ANWAR at 85%
# Highest low match: DR. CHOWDHURY FATEMA KABIR with 70%
# Match found: DR. NILUFAR YASMIN with DR. NILUFAR YASMIN at 100%
# Highest low match: DR. MD. NAIMUR RAHMAN with 62%
# Highest low match: DR. H KABIR with 53%
# Highest low match: DR. MAHAMUD MURSHID (SHUVO) with 74%
# Match found: DR. ABDUL HALIM with DR. ABDUL HALIM SARDER at 81%
# Highest low match: DR. KANOL SAHA with 62%
# Highest low match: DR. MD HASNAT with 77%
# Highest low match: DR. GOLAM RABBY CHOWDHURY (SWAKKHOR) with 56%
# Highest low match: DR. MAKSUDA FARIDA AKHTER (MILI) with 68%
# Match found: DR. SHIRIN AKHTAR with DR. SHIRIN AKTER at 91%
# ...
